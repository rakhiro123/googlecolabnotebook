# %% [markdown]
# <a href="https://colab.research.google.com/github/rakhiro123/googlecolabnotebook/blob/main/mynotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
a = 'hello';
b = 'world';
print(a+b);
# Out:
# helloworld

# %%
c = 'ridho'
print(a+b+c);
# Out:
# helloworldridho
